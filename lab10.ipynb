# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

# %%
def gaussian(batch, stochastic=False):
    if stochastic:
        return np.random.normal(batch)
    else:
        return np.copy(batch)

def gaussian_derivative(batch):
    return np.ones(batch.shape, dtype=np.float32)

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    if rbm.l2_penalty is not None:
        rbm.M[:-1, :-1] = rbm.M[:-1, :-1] - rbm.learning_rate * rbm.l2_penalty * rbm.W[:-1, :-1]

    rbm.W += rbm.M;
    
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size))
    
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(dbn[i].visible_act_func(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(dbn[i].hidden_act_func(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    error = reconstuction_error(dbn[layer_idx], propagated)
    return error

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))
        
        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # Autoencoder training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %%
def forward_pass(ae, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(ae):
        z = visible @ layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(ae) - 1):
            layer.d_activations = layer.d_activation_fun(z)
            
        visible = layer.activations

    return visible[:, :-1]

def error_backpropagate(ae, batch):
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(ae))):
        if layer_idx > 0:
            prev_layer = ae[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = (layer.deltas @ layer.W[:-1, :].T) * prev_layer.d_activations
        else:
            visible = batch
        
        layer.M *= layer.momentum
        layer.M -= (layer.learning_rate / observations_count) * (visible.T @ layer.deltas)
        
        if layer.l2_penalty > 0:
            layer.M[:-1, :] = layer.M[:-1, :] - layer.learning_rate * layer.l2_penalty * layer.W[:-1, :]
        
        layer.W += layer.M

# %% [markdown]
# ### Cross entropy cost

# %% [markdown]
# Implement cross entropy cost for deep AE. To this end:
# * calculate the cross entropy cost between pixels in the input batch and their reconstructions,
# * sum the cross entropy cost over all pixels and all observations in the minibatch,
# * return average cost per input observation.

# %%
def xentropy(batch, reconstructions):
    observations_count = batch.shape[0]
    
    return -np.sum(batch * np.log2(reconstructions + 1e-12) 
                   + ((1.0 - batch) * np.log2((1.0 - reconstructions) + 1e-12))) / observations_count

# %% [markdown]
# ### Training procedure

# %%
def train_ae(ae, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    batched_data = chunks(dataset, batch_size)
    
    for batch_idx, batch in enumerate(batched_data):
        reconstructions = forward_pass(ae, batch, True)

        ae[-1].deltas = reconstructions - batch[:,:-1]
        
        error_backpropagate(ae, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_ae_training(ae, train_set, validation_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print("\telapsed: {0:>2.2f}s, cross-entropy: {1:>2.2f}".format(elapsed, xe))

    print("Training finished!")

# %% [markdown]
# ###  Initializing AE with DBN weights
#
# Implement initialization of AE weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the AE weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_ae(ae, dbn):
    assert(len(ae) == 2*len(dbn))
    
    for dbn_layer, ae_layer in zip(dbn, ae):
        ae_layer.W = np.copy(dbn_layer.W[:,:-1])
    
    for dbn_layer, ae_layer in zip(dbn, reversed(ae)):
        ae_layer.W = np.copy(dbn_layer.W.T[:,:-1])

# %% [markdown]
# # Autoencoder for MNIST digits

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE

BATCH_SIZE = 128
EPOCHS_COUNT = 50

RBM_LEARNING_RATE = 0.1
AE_LEARNING_RATE = 0.01
AE_MOMENTUM = 0.9
L2_PENALTY = 0.0002

# %%
from IPython.core.display import HTML

def compare_results(ae, dbn,
                    train_set, validation_set, monitoring_set,
                    batch_size, epochs_count):
    for layer in ae:
        layer.reset()
    
    display(HTML('<h3>Plain AE training</h3>'))
    run_ae_training(ae, train_set, validation_set,
                    batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain AE</h3>'))
    draw_layer_filters(ae[0])
    
    display(HTML('<h3>Input minibatch</h3>'))
    tiles(np.reshape(validation_set[:8*24, :-1],
                     newshape=(8, 24, 28, 28)))
    
    display(HTML('<h3>Plain AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False),
                                    newshape=(8, 24, 28, 28))
    tiles(ae_reconstructions)
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in ae:
        layer.reset()
    
    initialize_ae(ae, dbn)
    dbn_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24, :], False),
                                     newshape=(8, 24, 28, 28))
    dbn_rec_cost = xentropy(validation_set[:, :-1],
                            forward_pass(ae, validation_set, False))
    
    display(HTML('<h3>Finetuning pretrained AE</h3>'))
    
    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_ae_training(ae, train_set, validation_set,
                    batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned AE</h3>'))
    draw_layer_filters(ae[0])
    
    display(HTML('<h3>Input minibatch</h3>'))
    tiles(np.reshape(validation_set[:8*24, :-1],
                     newshape=(8, 24, 28, 28)))
    
    display(HTML('<h3>Pretrained AE reconstructions</h3>'))
    tiles(dbn_reconstructions)
    
    display(HTML('<h3>Finetuned AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False),
                                    newshape=(8, 24, 28, 28))
    tiles(ae_reconstructions)

# %% [markdown]
# ###  Autoencoder network
#
# Define the autoencoder network for MNIST digits. The network structure should be suitable for pretraining with the provided DBN.

# %%
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(64, 10, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY)
]

ae =  [
    #ENC
    Layer(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(256, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(128, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),   
    Layer(64, 10, gaussian, gaussian_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    #DEC
    Layer(10, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(64, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(128, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
    Layer(256, VISIBLE_LAYER_SIZE, sigmoid, None, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY),
]

compare_results(ae, dbn,
                mnist_train_images, mnist_test_images,
                monitoring_set,
                BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain AE training</h3>
# Epoch 1:	########################################	elapsed: 1.10s, cross-entropy: 297.58
# Epoch 2:	########################################	elapsed: 1.11s, cross-entropy: 297.46
# Epoch 3:	########################################	elapsed: 1.14s, cross-entropy: 297.43
# Epoch 4:	########################################	elapsed: 1.16s, cross-entropy: 297.41
# Epoch 5:	########################################	elapsed: 1.07s, cross-entropy: 297.40
# Epoch 6:	########################################	elapsed: 1.07s, cross-entropy: 297.39
# Epoch 7:	########################################	elapsed: 1.07s, cross-entropy: 297.38
# Epoch 8:	########################################	elapsed: 1.10s, cross-entropy: 297.37
# Epoch 9:	########################################	elapsed: 1.09s, cross-entropy: 297.36
# Epoch 10:	########################################	elapsed: 1.08s, cross-entropy: 297.36
# Epoch 11:	########################################	elapsed: 1.08s, cross-entropy: 297.35
# Epoch 12:	########################################	elapsed: 1.06s, cross-entropy: 297.34
# Epoch 13:	########################################	elapsed: 1.08s, cross-entropy: 297.34
# Epoch 14:	########################################	elapsed: 1.13s, cross-entropy: 297.33
# Epoch 15:	########################################	elapsed: 1.14s, cross-entropy: 297.33
# Epoch 16:	########################################	elapsed: 1.75s, cross-entropy: 297.32
# Epoch 17:	########################################	elapsed: 1.11s, cross-entropy: 297.32
# Epoch 18:	########################################	elapsed: 1.06s, cross-entropy: 297.31
# Epoch 19:	########################################	elapsed: 1.08s, cross-entropy: 297.31
# Epoch 20:	########################################	elapsed: 0.97s, cross-entropy: 297.30
# Epoch 21:	########################################	elapsed: 1.24s, cross-entropy: 297.30
# Epoch 22:	########################################	elapsed: 1.49s, cross-entropy: 297.29
# Epoch 23:	########################################	elapsed: 1.70s, cross-entropy: 297.29
# Epoch 24:	########################################	elapsed: 1.02s, cross-entropy: 297.28
# Epoch 25:	########################################	elapsed: 1.05s, cross-entropy: 297.28
# Epoch 26:	########################################	elapsed: 1.03s, cross-entropy: 297.28
# Epoch 27:	########################################	elapsed: 1.05s, cross-entropy: 297.27
# Epoch 28:	########################################	elapsed: 1.09s, cross-entropy: 297.27
# Epoch 29:	########################################	elapsed: 1.06s, cross-entropy: 297.27
# Epoch 30:	########################################	elapsed: 1.06s, cross-entropy: 297.26
# Epoch 31:	########################################	elapsed: 1.05s, cross-entropy: 297.26
# Epoch 32:	########################################	elapsed: 1.04s, cross-entropy: 297.26
# Epoch 33:	########################################	elapsed: 1.19s, cross-entropy: 297.26
# Epoch 34:	########################################	elapsed: 1.12s, cross-entropy: 297.25
# Epoch 35:	########################################	elapsed: 1.10s, cross-entropy: 297.25
# Epoch 36:	########################################	elapsed: 1.05s, cross-entropy: 297.25
# Epoch 37:	########################################	elapsed: 1.04s, cross-entropy: 297.24
# Epoch 38:	########################################	elapsed: 1.03s, cross-entropy: 297.24
# Epoch 39:	########################################	elapsed: 1.04s, cross-entropy: 297.24
# Epoch 40:	########################################	elapsed: 1.06s, cross-entropy: 297.24
# Epoch 41:	########################################	elapsed: 1.07s, cross-entropy: 297.23
# Epoch 42:	########################################	elapsed: 1.11s, cross-entropy: 297.23
# Epoch 43:	########################################	elapsed: 1.08s, cross-entropy: 297.23
# Epoch 44:	########################################	elapsed: 1.06s, cross-entropy: 297.23
# Epoch 45:	########################################	elapsed: 1.04s, cross-entropy: 297.22
# Epoch 46:	########################################	elapsed: 1.03s, cross-entropy: 297.22
# Epoch 47:	########################################	elapsed: 1.04s, cross-entropy: 297.22
# Epoch 48:	########################################	elapsed: 1.04s, cross-entropy: 297.22
# Epoch 49:	########################################	elapsed: 1.10s, cross-entropy: 297.22
# Epoch 50:	########################################	elapsed: 1.11s, cross-entropy: 297.21
# Training finished!
# <h3>Input layer filters in the plain AE</h3>
# <h3>Input minibatch</h3>
# <h3>Plain AE reconstructions</h3>
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 0.85s, reconstruction error: 31.41
# Epoch 2:	########################################	elapsed: 0.99s, reconstruction error: 24.80
# Epoch 3:	########################################	elapsed: 0.85s, reconstruction error: 21.43
# Epoch 4:	########################################	elapsed: 0.83s, reconstruction error: 19.24
# Epoch 5:	########################################	elapsed: 0.86s, reconstruction error: 17.60
# Epoch 6:	########################################	elapsed: 0.91s, reconstruction error: 15.40
# Epoch 7:	########################################	elapsed: 0.84s, reconstruction error: 13.58
# Epoch 8:	########################################	elapsed: 0.82s, reconstruction error: 12.63
# Epoch 9:	########################################	elapsed: 0.82s, reconstruction error: 12.00
# Epoch 10:	########################################	elapsed: 0.81s, reconstruction error: 11.42
# Epoch 11:	########################################	elapsed: 0.86s, reconstruction error: 11.29
# Epoch 12:	########################################	elapsed: 0.81s, reconstruction error: 10.96
# Epoch 13:	########################################	elapsed: 0.80s, reconstruction error: 10.66
# Epoch 14:	########################################	elapsed: 0.82s, reconstruction error: 10.38
# Epoch 15:	########################################	elapsed: 0.81s, reconstruction error: 10.40
# Epoch 16:	########################################	elapsed: 0.81s, reconstruction error: 10.07
# Epoch 17:	########################################	elapsed: 0.81s, reconstruction error: 9.97
# Epoch 18:	########################################	elapsed: 1.09s, reconstruction error: 9.78
# Epoch 19:	########################################	elapsed: 1.43s, reconstruction error: 9.86
# Epoch 20:	########################################	elapsed: 1.23s, reconstruction error: 9.68
# Epoch 21:	########################################	elapsed: 0.98s, reconstruction error: 9.73
# Epoch 22:	########################################	elapsed: 1.13s, reconstruction error: 9.64
# Epoch 23:	########################################	elapsed: 1.02s, reconstruction error: 9.55
# Epoch 24:	########################################	elapsed: 0.81s, reconstruction error: 9.36
# Epoch 25:	########################################	elapsed: 0.80s, reconstruction error: 9.43
# Epoch 26:	########################################	elapsed: 0.81s, reconstruction error: 9.26
# Epoch 27:	########################################	elapsed: 0.82s, reconstruction error: 9.47
# Epoch 28:	########################################	elapsed: 0.84s, reconstruction error: 9.27
# Epoch 29:	########################################	elapsed: 0.83s, reconstruction error: 9.25
# Epoch 30:	########################################	elapsed: 0.82s, reconstruction error: 9.20
# Epoch 31:	########################################	elapsed: 0.83s, reconstruction error: 9.17
# Epoch 32:	########################################	elapsed: 0.85s, reconstruction error: 9.13
# Epoch 33:	########################################	elapsed: 0.89s, reconstruction error: 9.06
# Epoch 34:	########################################	elapsed: 0.85s, reconstruction error: 9.02
# Epoch 35:	########################################	elapsed: 0.88s, reconstruction error: 8.99
# Epoch 36:	########################################	elapsed: 0.84s, reconstruction error: 8.92
# Epoch 37:	########################################	elapsed: 0.81s, reconstruction error: 9.01
# Epoch 38:	########################################	elapsed: 0.81s, reconstruction error: 8.95
# Epoch 39:	########################################	elapsed: 0.85s, reconstruction error: 8.87
# Epoch 40:	########################################	elapsed: 0.84s, reconstruction error: 8.85
# Epoch 41:	########################################	elapsed: 0.82s, reconstruction error: 8.93
# Epoch 42:	########################################	elapsed: 1.23s, reconstruction error: 8.89
# Epoch 43:	########################################	elapsed: 0.81s, reconstruction error: 8.82
# Epoch 44:	########################################	elapsed: 0.85s, reconstruction error: 8.82
# Epoch 45:	########################################	elapsed: 0.82s, reconstruction error: 8.75
# Epoch 46:	########################################	elapsed: 0.82s, reconstruction error: 8.87
# Epoch 47:	########################################	elapsed: 0.81s, reconstruction error: 8.73
# Epoch 48:	########################################	elapsed: 0.80s, reconstruction error: 8.78
# Epoch 49:	########################################	elapsed: 0.80s, reconstruction error: 8.66
# Epoch 50:	########################################	elapsed: 0.80s, reconstruction error: 8.66
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 0.37s, reconstruction error: 20.32
# Epoch 2:	########################################	elapsed: 0.37s, reconstruction error: 15.66
# Epoch 3:	########################################	elapsed: 0.37s, reconstruction error: 13.52
# Epoch 4:	########################################	elapsed: 0.39s, reconstruction error: 12.10
# Epoch 5:	########################################	elapsed: 0.36s, reconstruction error: 11.08
# Epoch 6:	########################################	elapsed: 0.36s, reconstruction error: 9.35
# Epoch 7:	########################################	elapsed: 0.41s, reconstruction error: 8.15
# Epoch 8:	########################################	elapsed: 0.36s, reconstruction error: 7.53
# Epoch 9:	########################################	elapsed: 0.36s, reconstruction error: 7.14
# Epoch 10:	########################################	elapsed: 0.36s, reconstruction error: 6.94
# Epoch 11:	########################################	elapsed: 0.46s, reconstruction error: 6.67
# Epoch 12:	########################################	elapsed: 0.38s, reconstruction error: 6.56
# Epoch 13:	########################################	elapsed: 0.38s, reconstruction error: 6.30
# Epoch 14:	########################################	elapsed: 0.36s, reconstruction error: 6.19
# Epoch 15:	########################################	elapsed: 0.37s, reconstruction error: 6.17
# Epoch 16:	########################################	elapsed: 0.38s, reconstruction error: 5.92
# Epoch 17:	########################################	elapsed: 0.69s, reconstruction error: 5.84
# Epoch 18:	########################################	elapsed: 0.40s, reconstruction error: 5.88
# Epoch 19:	########################################	elapsed: 0.40s, reconstruction error: 5.80
# Epoch 20:	########################################	elapsed: 0.36s, reconstruction error: 5.84
# Epoch 21:	########################################	elapsed: 0.36s, reconstruction error: 5.70
# Epoch 22:	########################################	elapsed: 0.36s, reconstruction error: 5.63
# Epoch 23:	########################################	elapsed: 0.60s, reconstruction error: 5.61
# Epoch 24:	########################################	elapsed: 0.56s, reconstruction error: 5.52
# Epoch 25:	########################################	elapsed: 0.38s, reconstruction error: 5.50
# Epoch 26:	########################################	elapsed: 0.38s, reconstruction error: 5.42
# Epoch 27:	########################################	elapsed: 0.40s, reconstruction error: 5.36
# Epoch 28:	########################################	elapsed: 0.38s, reconstruction error: 5.41
# Epoch 29:	########################################	elapsed: 0.38s, reconstruction error: 5.36
# Epoch 30:	########################################	elapsed: 0.37s, reconstruction error: 5.37
# Epoch 31:	########################################	elapsed: 0.36s, reconstruction error: 5.28
# Epoch 32:	########################################	elapsed: 0.36s, reconstruction error: 5.28
# Epoch 33:	########################################	elapsed: 0.38s, reconstruction error: 5.26
# Epoch 34:	########################################	elapsed: 0.36s, reconstruction error: 5.23
# Epoch 35:	########################################	elapsed: 0.36s, reconstruction error: 5.18
# Epoch 36:	########################################	elapsed: 0.36s, reconstruction error: 5.17
# Epoch 37:	########################################	elapsed: 0.36s, reconstruction error: 5.19
# Epoch 38:	########################################	elapsed: 0.39s, reconstruction error: 5.11
# Epoch 39:	########################################	elapsed: 0.40s, reconstruction error: 5.20
# Epoch 40:	########################################	elapsed: 0.46s, reconstruction error: 5.12
# Epoch 41:	########################################	elapsed: 0.37s, reconstruction error: 5.13
# Epoch 42:	########################################	elapsed: 0.36s, reconstruction error: 5.08
# Epoch 43:	########################################	elapsed: 0.36s, reconstruction error: 5.07
# Epoch 44:	########################################	elapsed: 0.36s, reconstruction error: 5.11
# Epoch 45:	########################################	elapsed: 0.37s, reconstruction error: 5.12
# Epoch 46:	########################################	elapsed: 0.36s, reconstruction error: 5.04
# Epoch 47:	########################################	elapsed: 0.36s, reconstruction error: 5.00
# Epoch 48:	########################################	elapsed: 0.36s, reconstruction error: 5.10
# Epoch 49:	########################################	elapsed: 0.36s, reconstruction error: 4.99
# Epoch 50:	########################################	elapsed: 0.37s, reconstruction error: 5.06
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.28s, reconstruction error: 14.35
# Epoch 2:	########################################	elapsed: 0.28s, reconstruction error: 10.71
# Epoch 3:	########################################	elapsed: 0.30s, reconstruction error: 9.08
# Epoch 4:	########################################	elapsed: 0.28s, reconstruction error: 8.21
# Epoch 5:	########################################	elapsed: 0.28s, reconstruction error: 7.57
# Epoch 6:	########################################	elapsed: 0.28s, reconstruction error: 6.28
# Epoch 7:	########################################	elapsed: 0.28s, reconstruction error: 5.52
# Epoch 8:	########################################	elapsed: 0.28s, reconstruction error: 5.26
# Epoch 9:	########################################	elapsed: 0.28s, reconstruction error: 4.96
# Epoch 10:	########################################	elapsed: 0.28s, reconstruction error: 4.76
# Epoch 11:	########################################	elapsed: 0.28s, reconstruction error: 4.71
# Epoch 12:	########################################	elapsed: 0.27s, reconstruction error: 4.59
# Epoch 13:	########################################	elapsed: 0.28s, reconstruction error: 4.52
# Epoch 14:	########################################	elapsed: 0.28s, reconstruction error: 4.44
# Epoch 15:	########################################	elapsed: 0.29s, reconstruction error: 4.43
# Epoch 16:	########################################	elapsed: 0.28s, reconstruction error: 4.37
# Epoch 17:	########################################	elapsed: 0.27s, reconstruction error: 4.34
# Epoch 18:	########################################	elapsed: 0.27s, reconstruction error: 4.28
# Epoch 19:	########################################	elapsed: 0.28s, reconstruction error: 4.15
# Epoch 20:	########################################	elapsed: 0.28s, reconstruction error: 4.15
# Epoch 21:	########################################	elapsed: 0.28s, reconstruction error: 4.15
# Epoch 22:	########################################	elapsed: 0.28s, reconstruction error: 4.23
# Epoch 23:	########################################	elapsed: 0.28s, reconstruction error: 4.12
# Epoch 24:	########################################	elapsed: 0.27s, reconstruction error: 4.05
# Epoch 25:	########################################	elapsed: 0.28s, reconstruction error: 4.11
# Epoch 26:	########################################	elapsed: 0.27s, reconstruction error: 4.08
# Epoch 27:	########################################	elapsed: 0.28s, reconstruction error: 4.01
# Epoch 28:	########################################	elapsed: 0.28s, reconstruction error: 4.06
# Epoch 29:	########################################	elapsed: 0.29s, reconstruction error: 4.07
# Epoch 30:	########################################	elapsed: 0.28s, reconstruction error: 3.99
# Epoch 31:	########################################	elapsed: 0.27s, reconstruction error: 3.96
# Epoch 32:	########################################	elapsed: 0.27s, reconstruction error: 4.03
# Epoch 33:	########################################	elapsed: 0.54s, reconstruction error: 3.99
# Epoch 34:	########################################	elapsed: 0.29s, reconstruction error: 3.94
# Epoch 35:	########################################	elapsed: 0.27s, reconstruction error: 3.95
# Epoch 36:	########################################	elapsed: 0.27s, reconstruction error: 3.93
# Epoch 37:	########################################	elapsed: 0.28s, reconstruction error: 3.96
# Epoch 38:	########################################	elapsed: 0.28s, reconstruction error: 3.89
# Epoch 39:	########################################	elapsed: 0.27s, reconstruction error: 3.85
# Epoch 40:	########################################	elapsed: 0.28s, reconstruction error: 3.89
# Epoch 41:	########################################	elapsed: 0.27s, reconstruction error: 3.94
# Epoch 42:	########################################	elapsed: 0.27s, reconstruction error: 3.85
# Epoch 43:	########################################	elapsed: 0.27s, reconstruction error: 3.89
# Epoch 44:	########################################	elapsed: 0.30s, reconstruction error: 3.91
# Epoch 45:	########################################	elapsed: 0.28s, reconstruction error: 3.85
# Epoch 46:	########################################	elapsed: 0.28s, reconstruction error: 3.92
# Epoch 47:	########################################	elapsed: 0.28s, reconstruction error: 3.86
# Epoch 48:	########################################	elapsed: 0.28s, reconstruction error: 3.85
# Epoch 49:	########################################	elapsed: 0.29s, reconstruction error: 3.84
# Epoch 50:	########################################	elapsed: 0.30s, reconstruction error: 3.89
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.21s, reconstruction error: 11.59
# Epoch 2:	########################################	elapsed: 0.20s, reconstruction error: 10.16
# Epoch 3:	########################################	elapsed: 0.21s, reconstruction error: 9.33
# Epoch 4:	########################################	elapsed: 0.23s, reconstruction error: 8.94
# Epoch 5:	########################################	elapsed: 0.21s, reconstruction error: 8.65
# Epoch 6:	########################################	elapsed: 0.21s, reconstruction error: 8.47
# Epoch 7:	########################################	elapsed: 0.22s, reconstruction error: 8.59
# Epoch 8:	########################################	elapsed: 0.21s, reconstruction error: 8.69
# Epoch 9:	########################################	elapsed: 0.23s, reconstruction error: 8.70
# Epoch 10:	########################################	elapsed: 0.20s, reconstruction error: 8.81
# Epoch 11:	########################################	elapsed: 0.20s, reconstruction error: 8.90
# Epoch 12:	########################################	elapsed: 0.21s, reconstruction error: 9.03
# Epoch 13:	########################################	elapsed: 0.20s, reconstruction error: 9.06
# Epoch 14:	########################################	elapsed: 0.21s, reconstruction error: 9.06
# Epoch 15:	########################################	elapsed: 0.23s, reconstruction error: 9.11
# Epoch 16:	########################################	elapsed: 0.20s, reconstruction error: 9.15
# Epoch 17:	########################################	elapsed: 0.20s, reconstruction error: 9.20
# Epoch 18:	########################################	elapsed: 0.21s, reconstruction error: 9.20
# Epoch 19:	########################################	elapsed: 0.20s, reconstruction error: 9.25
# Epoch 20:	########################################	elapsed: 0.20s, reconstruction error: 9.29
# Epoch 21:	########################################	elapsed: 0.20s, reconstruction error: 9.29
# Epoch 22:	########################################	elapsed: 0.21s, reconstruction error: 9.29
# Epoch 23:	########################################	elapsed: 0.20s, reconstruction error: 9.30
# Epoch 24:	########################################	elapsed: 0.20s, reconstruction error: 9.33
# Epoch 25:	########################################	elapsed: 0.21s, reconstruction error: 9.32
# Epoch 26:	########################################	elapsed: 0.21s, reconstruction error: 9.33
# Epoch 27:	########################################	elapsed: 0.21s, reconstruction error: 9.32
# Epoch 28:	########################################	elapsed: 0.29s, reconstruction error: 9.37
# Epoch 29:	########################################	elapsed: 0.20s, reconstruction error: 9.37
# Epoch 30:	########################################	elapsed: 0.22s, reconstruction error: 9.40
# Epoch 31:	########################################	elapsed: 0.20s, reconstruction error: 9.42
# Epoch 32:	########################################	elapsed: 0.21s, reconstruction error: 9.44
# Epoch 33:	########################################	elapsed: 0.22s, reconstruction error: 9.43
# Epoch 34:	########################################	elapsed: 0.21s, reconstruction error: 9.42
# Epoch 35:	########################################	elapsed: 0.64s, reconstruction error: 9.48
# Epoch 36:	########################################	elapsed: 0.22s, reconstruction error: 9.48
# Epoch 37:	########################################	elapsed: 0.22s, reconstruction error: 9.52
# Epoch 38:	########################################	elapsed: 0.22s, reconstruction error: 9.48
# Epoch 39:	########################################	elapsed: 0.26s, reconstruction error: 9.52
# Epoch 40:	########################################	elapsed: 0.21s, reconstruction error: 9.53
# Epoch 41:	########################################	elapsed: 0.20s, reconstruction error: 9.56
# Epoch 42:	########################################	elapsed: 0.21s, reconstruction error: 9.59
# Epoch 43:	########################################	elapsed: 0.21s, reconstruction error: 9.59
# Epoch 44:	########################################	elapsed: 0.20s, reconstruction error: 9.60
# Epoch 45:	########################################	elapsed: 0.32s, reconstruction error: 9.61
# Epoch 46:	########################################	elapsed: 0.25s, reconstruction error: 9.64
# Epoch 47:	########################################	elapsed: 0.65s, reconstruction error: 9.64
# Epoch 48:	########################################	elapsed: 0.41s, reconstruction error: 9.68
# Epoch 49:	########################################	elapsed: 0.81s, reconstruction error: 9.68
# Epoch 50:	########################################	elapsed: 0.21s, reconstruction error: 9.68
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 192.08
#
# Epoch 1:	########################################	elapsed: 1.31s, cross-entropy: 152.37
# Epoch 2:	########################################	elapsed: 1.31s, cross-entropy: 148.28
# Epoch 3:	########################################	elapsed: 1.31s, cross-entropy: 145.64
# Epoch 4:	########################################	elapsed: 1.32s, cross-entropy: 143.64
# Epoch 5:	########################################	elapsed: 1.32s, cross-entropy: 142.16
# Epoch 6:	########################################	elapsed: 1.30s, cross-entropy: 141.03
# Epoch 7:	########################################	elapsed: 1.33s, cross-entropy: 140.11
# Epoch 8:	########################################	elapsed: 1.37s, cross-entropy: 139.31
# Epoch 9:	########################################	elapsed: 1.35s, cross-entropy: 138.63
# Epoch 10:	########################################	elapsed: 1.32s, cross-entropy: 138.06
# Epoch 11:	########################################	elapsed: 1.38s, cross-entropy: 137.56
# Epoch 12:	########################################	elapsed: 1.29s, cross-entropy: 137.13
# Epoch 13:	########################################	elapsed: 1.29s, cross-entropy: 136.76
# Epoch 14:	########################################	elapsed: 1.36s, cross-entropy: 136.42
# Epoch 15:	########################################	elapsed: 1.41s, cross-entropy: 136.12
# Epoch 16:	########################################	elapsed: 2.16s, cross-entropy: 135.85
# Epoch 17:	########################################	elapsed: 2.95s, cross-entropy: 135.64
# Epoch 18:	########################################	elapsed: 1.45s, cross-entropy: 135.61
# Epoch 19:	########################################	elapsed: 1.30s, cross-entropy: 135.33
# Epoch 20:	########################################	elapsed: 1.20s, cross-entropy: 134.43
# Epoch 21:	########################################	elapsed: 1.11s, cross-entropy: 134.58
# Epoch 22:	########################################	elapsed: 1.25s, cross-entropy: 134.42
# Epoch 23:	########################################	elapsed: 1.30s, cross-entropy: 134.28
# Epoch 24:	########################################	elapsed: 2.26s, cross-entropy: 135.04
# Epoch 25:	########################################	elapsed: 1.65s, cross-entropy: 134.94
# Epoch 26:	########################################	elapsed: 1.10s, cross-entropy: 134.46
# Epoch 27:	########################################	elapsed: 1.28s, cross-entropy: 135.81
# Epoch 28:	########################################	elapsed: 1.87s, cross-entropy: 133.45
# Epoch 29:	########################################	elapsed: 1.14s, cross-entropy: 134.02
# Epoch 30:	########################################	elapsed: 1.11s, cross-entropy: 133.80
# Epoch 31:	########################################	elapsed: 1.88s, cross-entropy: 133.82
# Epoch 32:	########################################	elapsed: 1.67s, cross-entropy: 134.36
# Epoch 33:	########################################	elapsed: 1.18s, cross-entropy: 134.23
# Epoch 34:	########################################	elapsed: 1.14s, cross-entropy: 133.77
# Epoch 35:	########################################	elapsed: 1.30s, cross-entropy: 134.27
# Epoch 36:	########################################	elapsed: 1.17s, cross-entropy: 133.16
# Epoch 37:	########################################	elapsed: 1.57s, cross-entropy: 132.84
# Epoch 38:	########################################	elapsed: 2.30s, cross-entropy: 134.21
# Epoch 39:	########################################	elapsed: 2.69s, cross-entropy: 134.28
# Epoch 40:	########################################	elapsed: 1.73s, cross-entropy: 132.52
# Epoch 41:	########################################	elapsed: 1.20s, cross-entropy: 131.88
# Epoch 42:	########################################	elapsed: 1.11s, cross-entropy: 131.41
# Epoch 43:	########################################	elapsed: 1.18s, cross-entropy: 131.22
# Epoch 44:	########################################	elapsed: 1.25s, cross-entropy: 130.54
# Epoch 45:	########################################	elapsed: 1.42s, cross-entropy: 130.39
# Epoch 46:	########################################	elapsed: 1.46s, cross-entropy: 130.63
# Epoch 47:	########################################	elapsed: 1.67s, cross-entropy: 130.76
# Epoch 48:	########################################	elapsed: 2.41s, cross-entropy: 130.47
# Epoch 49:	########################################	elapsed: 1.29s, cross-entropy: 130.38
# Epoch 50:	########################################	elapsed: 1.19s, cross-entropy: 130.59
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned AE</h3>
# <h3>Input minibatch</h3>
# <h3>Pretrained AE reconstructions</h3>
# <h3>Finetuned AE reconstructions</h3>
