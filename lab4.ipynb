# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, pc_count = None):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.pc_count = pc_count
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.PC = None if self.pc_count is None else append_ones(zeros(self.pc_count, self.hidden_size))

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:,:-1] = sigmoid(minibatch @ rbm.W[:,:-1])
    hidden[:,:-1] = 1.0*(hidden[:,:-1] > rand(*(hidden[:,:-1].shape)))
    
    visible = sigmoid(hidden @ rbm.W[:-1,:].T)
    
    error = (np.linalg.norm(minibatch[:,:-1] - visible) ** 2) / observations_count
    
    return error

# %% [markdown]
# ## Algorytm Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# W sieci RBM gradient funkcji kosztu względem wag wyznaczamy zgodnie ze wzorem:
#
# $\frac{\delta}{\delta w_{ij}} -\log P(\vect{v}) = -\mathbf{E}[v_i h_j \vert \vect{v}] + \mathbf{E}[v_i h_j]$
#
# #### Faza pozytywna - odpowiada za część $\mathbf{E}[v_i h_j \vert \vect{v}]$
#
# Tą część gradientu wyznaczamy przez wyliczenie iloczynów $v_i h_j$ pomiędzy elementami wektora obserwacji ($v_i$) a prawdopodobieństwami aktywacji w warstwie ukrytej ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_P = \vect{v}^T\sigma(\vect{vW})$
#
# #### Faza negatywna - odpowiada za część $\mathbf{E}[v_i h_j]$
#
# Rozpoczynamy od prawdopodobieństw aktywacji neuronów w warstwie ukrytej, które zostały wyznaczone w fazie pozytywnej. Na ich podstawie losujemy próbkę aktywacji w warstwie ukrytej:
#
# $\vect{h} = \sigma (\vect{vW}) > [rand_1, rand_2, \dots, rand_m]$
#
# Następnie losujemy próbkę aktywacji w warstwie widocznej:
#
# $\vect{v}_1 = \sigma (\vect{hW}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Aby wyznaczyć *fantazję* sieci RBM, powyższe próbki losujemy (naprzemiennie) $k$ razy (gdzie $k$ to parametr algorytmu CD-*k*):
#
# $\vect{h}_{k-1} = \sigma (\vect{v}_{k-1}\vect{W}) > [rand_1, rand_2, \dots, rand_m]$,
# $\vect{v}_k = \sigma (\vect{h}_{k-1}\vect{W}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Część negatywną gradientu wyznaczamy poprzez wyliczenie iloczynów $v_{k_i} h_j$ pomiędzy elementami wektora *fantazji* RBM ($v_{k_i}$) a prawdopodobieństwami aktywacji w warstwie ukrytej wyliczonymi dla tejże *fantazji* ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_N = \vect{v}_k^T\sigma(\vect{v}_k\vect{W})$
#
#
# #### Aktualizacja macierzy wag RBM
#
# Uczymy stochastycznym spadkiem wzdłuż gradientu:
#
# $\phi_{t+1} \leftarrow \phi_t - \epsilon \nabla$
#
# co dla gradientu RBM daje:
#
# $W_{t+1} \leftarrow W_t + \epsilon \nabla_P - \epsilon \nabla_N$

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    # positive
    positive_hidden[:,:-1] = sigmoid(positive_visible @ rbm.W[:,:-1])
    
    positive_gradient = (positive_visible.T @ positive_hidden) / observations_count
    
    # negative
    negative_hidden[:,:-1] = 1.0*(positive_hidden[:,:-1] > rand(*(positive_hidden[:,:-1].shape)))
    
    negative_visible[:,:-1] = sigmoid(negative_hidden @ rbm.W[:-1,:].T)
    negative_visible[:,:-1] = 1.0*(negative_visible[:,:-1] > rand(*(negative_visible[:,:-1].shape)))
    
    for _ in range(k-1):
        negative_hidden[:,:-1] = sigmoid(negative_visible @ rbm.W[:,:-1])
        negative_hidden[:,:-1] = 1.0*(negative_hidden[:,:-1] > rand(*(negative_hidden[:,:-1].shape))) 
        
        negative_visible[:,:-1] = sigmoid(negative_hidden @ rbm.W[:-1,:].T)
        negative_visible[:,:-1] = 1.0*(negative_visible[:,:-1] > rand(*(negative_visible[:,:-1].shape)))
    
    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
    negative_gradient = (negative_visible.T @ negative_hidden) / observations_count
    
    rbm.W = rbm.W + rbm.learning_rate * (positive_gradient - negative_gradient)

# %% [markdown]
# ## Algorytm Persistent Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# Algorytm Persistent Contrastive Divergence (PCD) różni się od algorytmu CD przebiegiem fazy negatywnej. Faza pozytywna przebiega w PCD tak samo jak w algorytmie CD.
#
# W PCD faza negatywna rozpoczyna się od nie od przykładu uczącego, lecz od stanu *wirtualnych cząstek*, który został został zapamiętany w poprzedniej fazie negatywnej:
#
# $\vect{h} = \vect{p}$,
#
# gdzie $\vect{p}$ to macierz przechowująca stan *wirtualnych cząstek*. Po inicjalizacji negatywnego stanu ukrytego ($\vect{h}$) rozpoczynamy próbkowanie Gibbsa i wyznaczamy fantazję sieci ($\vect{v}_k$). Następnie zapamiętujemy nowy stan wirtualnych cząstek:
#
# $\vect{p} = \sigma (\vect{v}_k\vect{W}) > [rand_1, rand_2, \dots, rand_m]$.
#
# Na koniec aktualizujemy wagi RBM. Aktualizacja wag przebiega tak samo jak w algorytmie CD.

# %%
def pcd(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]
    
    positive_visible = minibatch
    negative_visible = append_ones(zeros(rbm.pc_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(rbm.pc_count, rbm.hidden_size))
    
    # positive
    positive_hidden[:,:-1] = sigmoid(positive_visible @ rbm.W[:,:-1])
    
    positive_gradient = (positive_visible.T @ positive_hidden) / observations_count
    
    #negative
    for _ in range(k):
        negative_visible[:, :-1] = sigmoid(rbm.PC @ rbm.W[:-1, :].T)
        negative_visible[:, :-1] = 1.0 * (negative_visible[:, :-1] > rand(*(negative_visible[:, :-1].shape)))
        
        negative_hidden[:, :-1]  = sigmoid(negative_visible @ rbm.W[:, :-1])
        rbm.PC[:, :-1] = 1.0 * (negative_hidden[:, :-1] > rand(*(negative_hidden[:, :-1].shape)))
        
    negative_gradient = (negative_visible.T @ negative_hidden) / rbm.pc_count
    
    rbm.W = rbm.W + rbm.learning_rate * (positive_gradient - negative_gradient)

# %% [markdown]
# # RBM Training

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)
    
def draw_samples(rbm, initial_batch, steps=200):
    tiles(np.reshape(sample_rbm(rbm, initial_batch, steps)[:, :-1], (-1, 24, 28, 28)))

# %%
def train_epoch(rbm, dataset, batch_size, training_algorithm=cdk):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        training_algorithm(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count, training_algorithm=cdk):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size, training_algorithm)

        elapsed = time.time() - start_time
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %% [markdown]
# ## CDK Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 60

CDK_LEARNING_RATE = 0.1

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, CDK_LEARNING_RATE)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, cdk)

draw_filters(rbm)
draw_samples(rbm, monitoring_set[:10*24])
# Out:
# Epoch 0:	#####################################################	elapsed: 1.17s, reconstruction error: 32.25
# Epoch 1:	#####################################################	elapsed: 1.09s, reconstruction error: 26.09
# Epoch 2:	#####################################################	elapsed: 1.10s, reconstruction error: 22.68
# Epoch 3:	#####################################################	elapsed: 1.13s, reconstruction error: 20.68
# Epoch 4:	#####################################################	elapsed: 1.11s, reconstruction error: 19.25
# Epoch 5:	#####################################################	elapsed: 1.20s, reconstruction error: 18.37
# Epoch 6:	#####################################################	elapsed: 1.16s, reconstruction error: 17.41
# Epoch 7:	#####################################################	elapsed: 1.15s, reconstruction error: 16.91
# Epoch 8:	#####################################################	elapsed: 1.29s, reconstruction error: 16.38
# Epoch 9:	#####################################################	elapsed: 1.10s, reconstruction error: 15.93
# Epoch 10:	#####################################################	elapsed: 1.16s, reconstruction error: 15.50
# Epoch 11:	#####################################################	elapsed: 1.18s, reconstruction error: 15.07
# Epoch 12:	#####################################################	elapsed: 1.27s, reconstruction error: 14.88
# Epoch 13:	#####################################################	elapsed: 1.34s, reconstruction error: 14.41
# Epoch 14:	#####################################################	elapsed: 1.01s, reconstruction error: 14.20
# Epoch 15:	#####################################################	elapsed: 0.98s, reconstruction error: 13.97
# Epoch 16:	#####################################################	elapsed: 1.19s, reconstruction error: 13.96
# Epoch 17:	#####################################################	elapsed: 1.09s, reconstruction error: 13.59
# Epoch 18:	#####################################################	elapsed: 0.96s, reconstruction error: 13.50
# Epoch 19:	#####################################################	elapsed: 1.07s, reconstruction error: 13.29
# Epoch 20:	#####################################################	elapsed: 1.10s, reconstruction error: 13.10
# Epoch 21:	#####################################################	elapsed: 1.17s, reconstruction error: 12.96
# Epoch 22:	#####################################################	elapsed: 1.10s, reconstruction error: 12.75
# Epoch 23:	#####################################################	elapsed: 1.12s, reconstruction error: 12.70
# Epoch 24:	#####################################################	elapsed: 1.47s, reconstruction error: 12.37
# Epoch 25:	#####################################################	elapsed: 1.20s, reconstruction error: 12.65
# Epoch 26:	#####################################################	elapsed: 1.06s, reconstruction error: 12.36
# Epoch 27:	#####################################################	elapsed: 1.11s, reconstruction error: 12.22
# Epoch 28:	#####################################################	elapsed: 1.01s, reconstruction error: 12.14
# Epoch 29:	#####################################################	elapsed: 1.14s, reconstruction error: 12.13
# Epoch 30:	#####################################################	elapsed: 0.99s, reconstruction error: 12.04
# Epoch 31:	#####################################################	elapsed: 1.29s, reconstruction error: 11.86
# Epoch 32:	#####################################################	elapsed: 1.27s, reconstruction error: 11.84
# Epoch 33:	#####################################################	elapsed: 1.02s, reconstruction error: 11.66
# Epoch 34:	#####################################################	elapsed: 0.94s, reconstruction error: 11.80
# Epoch 35:	#####################################################	elapsed: 1.05s, reconstruction error: 11.60
# Epoch 36:	#####################################################	elapsed: 1.09s, reconstruction error: 11.61
# Epoch 37:	#####################################################	elapsed: 1.07s, reconstruction error: 11.41
# Epoch 38:	#####################################################	elapsed: 1.06s, reconstruction error: 11.69
# Epoch 39:	#####################################################	elapsed: 1.09s, reconstruction error: 11.30
# Epoch 40:	#####################################################	elapsed: 1.10s, reconstruction error: 11.29
# Epoch 41:	#####################################################	elapsed: 1.07s, reconstruction error: 11.33
# Epoch 42:	#####################################################	elapsed: 1.11s, reconstruction error: 11.28
# Epoch 43:	#####################################################	elapsed: 1.48s, reconstruction error: 11.17
# Epoch 44:	#####################################################	elapsed: 1.12s, reconstruction error: 11.20
# Epoch 45:	#####################################################	elapsed: 1.14s, reconstruction error: 11.18
# Epoch 46:	#####################################################	elapsed: 1.06s, reconstruction error: 11.19
# Epoch 47:	#####################################################	elapsed: 1.07s, reconstruction error: 11.01
# Epoch 48:	#####################################################	elapsed: 1.08s, reconstruction error: 10.99
# Epoch 49:	#####################################################	elapsed: 1.22s, reconstruction error: 11.12
# Epoch 50:	#####################################################	elapsed: 1.08s, reconstruction error: 10.88
# Epoch 51:	#####################################################	elapsed: 0.97s, reconstruction error: 11.01
# Epoch 52:	#####################################################	elapsed: 0.96s, reconstruction error: 11.03
# Epoch 53:	#####################################################	elapsed: 0.95s, reconstruction error: 10.86
# Epoch 54:	#####################################################	elapsed: 0.94s, reconstruction error: 10.82
# Epoch 55:	#####################################################	elapsed: 0.94s, reconstruction error: 10.76
# Epoch 56:	#####################################################	elapsed: 1.06s, reconstruction error: 10.87
# Epoch 57:	#####################################################	elapsed: 1.15s, reconstruction error: 10.69
# Epoch 58:	#####################################################	elapsed: 0.99s, reconstruction error: 10.81
# Epoch 59:	#####################################################	elapsed: 0.94s, reconstruction error: 10.78
# Training finished!

# %% [markdown]
# ## PCD Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 60

PCD_PARTICLES_COUNT = 128
PCD_LEARNING_RATE = 0.01

rbm_pcd = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, PCD_LEARNING_RATE, PCD_PARTICLES_COUNT)
draw_filters(rbm_pcd)

run_training(rbm_pcd, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, pcd)

draw_filters(rbm_pcd)
draw_samples(rbm_pcd, monitoring_set[:10*24])
# Out:
# Epoch 0:	#####################################################	elapsed: 0.97s, reconstruction error: 81.92
# Epoch 1:	#####################################################	elapsed: 1.08s, reconstruction error: 59.98
# Epoch 2:	#####################################################	elapsed: 1.09s, reconstruction error: 47.39
# Epoch 3:	#####################################################	elapsed: 1.10s, reconstruction error: 41.57
# Epoch 4:	#####################################################	elapsed: 1.11s, reconstruction error: 38.04
# Epoch 5:	#####################################################	elapsed: 1.11s, reconstruction error: 36.07
# Epoch 6:	#####################################################	elapsed: 1.10s, reconstruction error: 35.30
# Epoch 7:	#####################################################	elapsed: 1.10s, reconstruction error: 35.04
# Epoch 8:	#####################################################	elapsed: 1.10s, reconstruction error: 34.54
# Epoch 9:	#####################################################	elapsed: 1.12s, reconstruction error: 32.61
# Epoch 10:	#####################################################	elapsed: 1.14s, reconstruction error: 31.88
# Epoch 11:	#####################################################	elapsed: 1.13s, reconstruction error: 30.75
# Epoch 12:	#####################################################	elapsed: 1.21s, reconstruction error: 29.50
# Epoch 13:	#####################################################	elapsed: 1.15s, reconstruction error: 29.27
# Epoch 14:	#####################################################	elapsed: 1.14s, reconstruction error: 27.99
# Epoch 15:	#####################################################	elapsed: 1.11s, reconstruction error: 28.11
# Epoch 16:	#####################################################	elapsed: 1.10s, reconstruction error: 27.41
# Epoch 17:	#####################################################	elapsed: 1.09s, reconstruction error: 26.84
# Epoch 18:	#####################################################	elapsed: 1.06s, reconstruction error: 26.06
# Epoch 19:	#####################################################	elapsed: 1.06s, reconstruction error: 25.92
# Epoch 20:	#####################################################	elapsed: 0.94s, reconstruction error: 25.50
# Epoch 21:	#####################################################	elapsed: 0.95s, reconstruction error: 25.42
# Epoch 22:	#####################################################	elapsed: 0.95s, reconstruction error: 24.71
# Epoch 23:	#####################################################	elapsed: 0.96s, reconstruction error: 24.45
# Epoch 24:	#####################################################	elapsed: 1.02s, reconstruction error: 24.17
# Epoch 25:	#####################################################	elapsed: 1.06s, reconstruction error: 23.76
# Epoch 26:	#####################################################	elapsed: 0.95s, reconstruction error: 23.31
# Epoch 27:	#####################################################	elapsed: 0.94s, reconstruction error: 22.95
# Epoch 28:	#####################################################	elapsed: 0.95s, reconstruction error: 22.74
# Epoch 29:	#####################################################	elapsed: 1.03s, reconstruction error: 22.41
# Epoch 30:	#####################################################	elapsed: 0.96s, reconstruction error: 21.90
# Epoch 31:	#####################################################	elapsed: 0.95s, reconstruction error: 21.62
# Epoch 32:	#####################################################	elapsed: 0.95s, reconstruction error: 21.31
# Epoch 33:	#####################################################	elapsed: 0.94s, reconstruction error: 20.91
# Epoch 34:	#####################################################	elapsed: 0.95s, reconstruction error: 20.59
# Epoch 35:	#####################################################	elapsed: 0.95s, reconstruction error: 20.47
# Epoch 36:	#####################################################	elapsed: 0.95s, reconstruction error: 19.87
# Epoch 37:	#####################################################	elapsed: 0.94s, reconstruction error: 20.15
# Epoch 38:	#####################################################	elapsed: 0.95s, reconstruction error: 19.64
# Epoch 39:	#####################################################	elapsed: 0.95s, reconstruction error: 18.78
# Epoch 40:	#####################################################	elapsed: 0.96s, reconstruction error: 18.94
# Epoch 41:	#####################################################	elapsed: 0.95s, reconstruction error: 18.61
# Epoch 42:	#####################################################	elapsed: 0.94s, reconstruction error: 18.26
# Epoch 43:	#####################################################	elapsed: 0.94s, reconstruction error: 18.10
# Epoch 44:	#####################################################	elapsed: 0.96s, reconstruction error: 17.99
# Epoch 45:	#####################################################	elapsed: 1.80s, reconstruction error: 17.62
# Epoch 46:	#####################################################	elapsed: 1.15s, reconstruction error: 17.51
# Epoch 47:	#####################################################	elapsed: 1.13s, reconstruction error: 17.42
# Epoch 48:	#####################################################	elapsed: 1.12s, reconstruction error: 16.86
# Epoch 49:	#####################################################	elapsed: 1.16s, reconstruction error: 16.66
# Epoch 50:	#####################################################	elapsed: 1.11s, reconstruction error: 16.46
# Epoch 51:	#####################################################	elapsed: 1.11s, reconstruction error: 16.13
# Epoch 52:	#####################################################	elapsed: 1.09s, reconstruction error: 16.11
# Epoch 53:	#####################################################	elapsed: 1.12s, reconstruction error: 16.05
# Epoch 54:	#####################################################	elapsed: 1.14s, reconstruction error: 15.62
# Epoch 55:	#####################################################	elapsed: 1.13s, reconstruction error: 15.21
# Epoch 56:	#####################################################	elapsed: 1.17s, reconstruction error: 15.27
# Epoch 57:	#####################################################	elapsed: 1.12s, reconstruction error: 15.00
# Epoch 58:	#####################################################	elapsed: 1.08s, reconstruction error: 14.70
# Epoch 59:	#####################################################	elapsed: 1.08s, reconstruction error: 14.62
# Training finished!
